# %% [markdown]
# # 1. Install Docker and create Dockerfiles to containerize applications?

# %% [markdown]
# ****INSTALL DOCKER****

# %% [markdown]
# * **Step 1: Update the Applciation Package Tool and install the Docker**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# * **Step 2: Now we enable the Docker and add the User in Docker group**

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# * **Step 3: Check the Docker Version**

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ****Create Dockerfiles to Containerize Application****

# %% [markdown]
# Each application gets a Dockerfile, defining how to package it into a container

# %% [markdown]
# **Example: Containerizing a Simple nginx application**

# %% [markdown]
# * **Step 1: Create the Dockerfile**

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# * **Step 2: Now Build the Image**

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# * **Step 3: Check the image that is installed**

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# * **Step 4: Run the Container at port 8080**

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# * **Step5: Check the container at web browser**

# %% [markdown]
# ![9.png](data:image/png;base64,...)
