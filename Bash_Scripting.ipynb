# %% [markdown]
# # 1. Task 1: File Management Script
# * Write a Bash script that
#     * Creates a directory named "backup" in the user's home directory
#     * Copies all .txt files from the current directory into the "backup" directory
#     * Appends the current date and time to the filenames of the copied files

# %% [markdown]
# Here's a Bash script that performs the required file management tasks

# %% [markdown]
# ![Screenshot 2025-05-31 211337.png](data:image/png;base64,...)

# %% [markdown]
# **Save the script as backup.sh**

# %% [markdown]
# ![Screenshot 2025-05-31 211417.png](data:image/png;base64,...)

# %% [markdown]
# **Make it executable:**

# %% [markdown]
# ![Screenshot 2025-05-31 211440.png](data:image/png;base64,...)

# %% [markdown]
# **Run it in the directory containing .txt files**

# %% [markdown]
# ![Screenshot 2025-05-31 211501.png](data:image/png;base64,...)

# %% [markdown]
# # 2.Task: System Health Check
#
# * Create a script that
#     * Checks the system’s CPU and memory usage
#     * Reports if the CPU usage is above 80% or if the available memory is below 20%
#     * Logs the results to a file named system_health.log

# %% [markdown]
# Here’s a Bash script that performs a system health check by monitoring CPU and memory usage:

# %% [markdown]
# ![Screenshot 2025-05-31 211922.png](data:image/png;base64,...)

# %% [markdown]
# **Make it executable:**![Screenshot 2025-05-31 212017.png](data:image/png;base64,...)

# %% [markdown]
# **Run it:**

# %% [markdown]
# ![Screenshot 2025-05-31 212047.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Task 3: User Account Management
# * Write a script thatg
#     * Reads a list of usernames from a file (e.g., user_list.txt)
#     * Creates a new user for each username
#     * Generates a random password for each user and saves the username and password to a file named credentials.txt.

# %% [markdown]
# Here's a Bash script that accomplishes the user account management tasks:

# %% [markdown]
# ![Screenshot 2025-05-31 212518.png](data:image/png;base64,...)

# %% [markdown]
# **Make the script executable:**

# %% [markdown]
# ![Screenshot 2025-05-31 212558.png](data:image/png;base64,...)

# %% [markdown]
# **Run it with sudo privileges:**

# %% [markdown]
# ![Screenshot 2025-05-31 212633.png](data:image/png;base64,...)

# %% [markdown]
# # 4.Task 4: Automated Backup
#
# * Create a script that
#     * Takes a directory path as input from the user
#     * Compresses the directory into a .tar.gz file
#     * Saves the compressed file with a name that includes the current date (e.g., backup_2023-08-20.tar.gz).

# %% [markdown]
# **Here's a Bash script that automates the backup process:**

# %% [markdown]
# ![Screenshot 2025-05-31 212934.png](data:image/png;base64,...)

# %% [markdown]
# **Make it executable:**

# %% [markdown]
# ![Screenshot 2025-05-31 213012.png](data:image/png;base64,...)

# %% [markdown]
# **Run the script:**

# %% [markdown]
# ![Screenshot 2025-05-31 213103.png](data:image/png;base64,...)

# %% [markdown]
# # 5. Task 5: Simple To-Do List
#
# * Create a Bash script thatg
#     * Implements a simple command-line to-do list
#     * Allows the user to add tasks, view tasks, and remove tasks
#     * Saves the tasks to a file (e.g., todo.txt).

# %% [markdown]
# Here's a Bash script that implements a simple command-line To-Do List system:

# %% [markdown]
# ![Screenshot 2025-05-31 213341.png](data:image/png;base64,...)

# %% [markdown]
# **Make it executable:**

# %% [markdown]
# ![Screenshot 2025-05-31 213403.png](data:image/png;base64,...)

# %% [markdown]
# **Run it:**

# %% [markdown]
# ![Screenshot 2025-05-31 213424.png](data:image/png;base64,...)

# %% [markdown]
# # 6. Task 7: Text File Processing
# * Create a script that
#     * Takes a text file as input
#     * Counts and displays the number of lines, words, and characters in the file
#     * Finds and displays the longest word in the file

# %% [markdown]
# Here's a Bash script that processes a text file by counting lines, words, and characters, and also finds the longest word

# %% [markdown]
# ![Screenshot 2025-05-31 213700.png](data:image/png;base64,...)

# %% [markdown]
# **Make it Executable**

# %% [markdown]
# ![Screenshot 2025-05-31 213735.png](data:image/png;base64,...)

# %% [markdown]
# **Run**

# %% [markdown]
# ![Screenshot 2025-05-31 213801.png](data:image/png;base64,...)
