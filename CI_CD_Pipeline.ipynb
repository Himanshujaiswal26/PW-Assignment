# %% [markdown]
# # 1.  Continuous Integration (CI)
#
# # Task 1: Set Up a CI Pipeline
#
# # Objective: Set up a basic CI pipeline that builds a project automatically whenever new code is pushed.
#
# # Tools: GitHub Actions, Jenkins, GitLab CI, or CircleCI
#
# # Instructions
# * **Create a simple application (use Node.js, Python, or Java)**
# * **Set up a repository on GitHub or GitLab**
# * **Configure a CI tool to automatically build the application whenever new code is pushed to the repository**
# * **Document each step with screenshots showing the pipeline running.**

# %% [markdown]
# **1. Create a Basic Application**
#
# * Initialize a Project
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# * Create a server.js
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# * Create a test.js
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# * Install testing Dependencies
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# **2. Set up a repository on GitHub or GitLab**
#
# * Initailize a Git Repository & add the nodes.gitignore
# ![Step2.1.png](data:image/png;base64,...)

# %% [markdown]
# * Commit and push the code to Github or GitLab
# ![Step2.2.png](data:image/png;base64,...)

# %% [markdown]
# **3. Configure a CI Pipeline**

# %% [markdown]
# **Github Actions (For GitHub Users)**
#
# * Create a .github-workflows.yml
# ![Step3.1.png](data:image/png;base64,...)

# %% [markdown]
# **GitLab CI/CD (For GitLab users)**
#
# * Create a .github-ci.yml
# ![Step3.2.png](data:image/png;base64,...)

# %% [markdown]
# **Jenkins (For Jenkins users)**
#
# * Install Jenkins and add the Node.js plugin.
# * Create a new Pipeline Job name Pipeline.groovy
# ![Jenkins step 3.3.png](data:image/png;base64,...)

# %% [markdown]
# **CircleCI (for CircleCI users)**
# * Create a .circleci-config.yml
# ![Step3.4.png](data:image/png;base64,...)

# %% [markdown]
# **4. Test and Document the Pipeline**
#
# * Push Changes to your repository
# ![Step3.5.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Jenkins
# # Task 2: Automated Build with Jenkins
# # Objective: Install Jenkins and configure an automated build job.
# #Tools: Jenkins, Docker (optional)
#
# # Instructions
# * Install Jenkins on your local machine or use a cloud platform (like AWS, Azure)
# * Set up a simple job that clones a Git repository and builds the project (eg. a Java project using Maven or a Node.js project)
# * Set up a trigger to run the job automatically when new code is pushed to the repository
# * Take screenshots of the Jenkins job and the build logs to demonstrate success.

# %% [markdown]
# **Step 1: Install Jenkins**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 2: Configure Jenkin**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 3: Set Up an Automated Build Job**
# * Navigate to New Item > Freestyle Project and give it a name.
# - Under Source Code Management, select Git and provide the repository URL.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * If it’s a Java project, under Build Steps, select Invoke Maven, and enter clean package as the goal.
# - If it’s a Node.js project, add a shell script step:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 4: Add an Automatic Trigger**
#
# - Go to Build Triggers, enable Poll SCM, and set the interval (e.g., H/5 * * * * to check every 5 minutes).
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 5: Run the Job and Capture Screenshots**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Testing Frameworks and Practices
#
# # Task 3: Write Unit Tests for an Application
#
# # Objective: Write unit tests for a simple application and integrate them into a CI pipeline.
#
# # Tools: Jest (JavaScript), JUnit (Java), pytest (Python)
#
#
# # Instructions
# * Create a small application (e.g., a calculator, to-do list, or API)
# * Write unit tests for the core functions (e.g., add, delete, or update functions)
# * Integrate these tests into a CI pipeline using GitHub Actions, Jenkins, or GitLab CI
# * Document your work with screenshots showing the tests running in the CI pipeline.

# %% [markdown]
# **Step 1: Create a Simple Application**
# * You can develop a basic calculator.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 2: Write Unit Tests**
# * Choose a testing framework:
#      * Jest for JavaScript
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Run tests:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Step 3: Integrate Tests into CI Pipeline**
# - GitHub Actions:
#   - Create .github/workflows/ci.yml
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Integration Testing
# # Task 4: Set Up Integration Testing for an API
# # Objective: Write integration tests for a REST API and automate them in a CI pipeline.
# # Tools: Postman, Newman, or Selenium (for web UI testing)
# # Instructions
# * Create a simple REST API (using Node.js, Python Flask, or Java Spring Boot)
# * Write integration tests to check the interaction between different components (e.g., database and API)
# * Set up the tests to run automatically in a Jenkins or GitLab CI pipeline after each deployment to a staging environment
# * Capture screenshots showing successful test execution.

# %% [markdown]
# **Step 1: Create a Simple REST API**
#
# * Install Dependencies
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Create server.js
# ![image.png](data:image/png;base64,...)
