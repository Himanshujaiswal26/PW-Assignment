# %% [markdown]
# # Install and configure Ansible, Puppet, or Chef on a local or cloud environment. Write and execute basic configuration scripts.?

# %% [markdown]
# **Ansible**

# %% [markdown]
# * **Install Ansible on Linux (Ubuntu)**
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# * **Configure Ansible Inventory**
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# * **Now, Write a basic Ansible Playbook**
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# * **Run Playbook**
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# **Install and Configure PUPPET**

# %% [markdown]
# * **Install Puppet on Ubuntu**
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# * **Write a Puppet Manifest Example**
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# * **Run the Puppet Script**
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# **Install and Configure CHEF**

# %% [markdown]
# * **Install Chef Workstation**
# ![1.png](data:image/png;base64,...)
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# * **Create a Basic Cookbook**
# ![3.1.png](data:image/png;base64,...)
# ![3.2.png](data:image/png;base64,...)

# %% [markdown]
# * **Now, Add a Recipe**
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# * **Run the Chef Recipe**
# ![5.png](data:image/png;base64,...)
